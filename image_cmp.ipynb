# %% [markdown]
# <a href="https://colab.research.google.com/github/maverick98/CDS/blob/main/image_cmp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.preprocessing import image
from keras.models import Model
from scipy.spatial.distance import cosine

class ImageSimilarity:
    def __init__(self):
        # Load the VGG16 model with ImageNet weights, excluding the top dense layers
        base_model = VGG16(weights='imagenet')
        self.model = Model(inputs=base_model.input, outputs=base_model.get_layer('fc1').output)

    def extract_features(self, img_path):
        """
        Extract features from an image using the VGG16 model.

        Parameters:
        img_path (str): The file path to the image.

        Returns:
        np.ndarray: The extracted feature vector.
        """
        img = image.load_img(img_path, target_size=(224, 224))
        img_data = image.img_to_array(img)
        img_data = np.expand_dims(img_data, axis=0)
        img_data = preprocess_input(img_data)
        features = self.model.predict(img_data)
        features = features.flatten()
        return features

    def compute_similarity(self, image1, image2):
        """
        Compute the similarity between two images based on their extracted features.

        Parameters:
        image1 (str): The file path to the first image.
        image2 (str): The file path to the second image.

        Returns:
        float: The cosine similarity between the two images.
        """
        features1 = self.extract_features(image1)
        features2 = self.extract_features(image2)

        # Compute the cosine similarity between the feature vectors
        similarity_score = 1 - cosine(features1, features2)
        print(f'Similarity Score: {similarity_score}')
        return similarity_score

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


def display_images(image1,image2):
    # Load the images
    img1 = mpimg.imread(image1)
    img2 = mpimg.imread(image2)
    # Create a figure with two subplots side by side
    fig, ax = plt.subplots(1, 2, figsize=(10, 5))

    # Display the first image
    ax[0].imshow(img1)
    ax[0].axis('off')  # Hide the axis
    ax[0].set_title('Image 1')

    # Display the second image
    ax[1].imshow(img2)
    ax[1].axis('off')  # Hide the axis
    ax[1].set_title('Image 2')

    # Show the plot
    plt.show()

# %%
similarity_calculator = ImageSimilarity()
# Out:
# ...
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 7s 0us/step

# %%
image1='/content/6-TestCase-50_1_testing.png'
image2='/content/6-TestCase-50_1_training.png'
display_images(image1,image2)
similarity_calculator.compute_similarity(image1,image2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 604ms/step
# Similarity Score: 0.9785593266946908
# 0.9785593266946908

# %%
image1='/content/38-TestCase-190_1_testing.png'
image2='/content/38-TestCase-190_1_training.png'
display_images(image1,image2)
similarity_calculator.compute_similarity(image1,image2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 860ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 651ms/step
# Similarity Score: 0.9795724910967766
# 0.9795724910967766

# %%
image1='/content/57-TestCase-260_1_testing.png'
image2='/content/57-TestCase-260_1_training.png'
display_images(image1,image2)
similarity_calculator.compute_similarity(image1,image2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 699ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 642ms/step
# Similarity Score: 0.9022089413704252
# 0.9022089413704252

# %%
image1='/content/1-TestCase-20_1_testing.png'
image2='/content/1-TestCase-20_1_training.png'
display_images(image1,image2)
similarity_calculator.compute_similarity(image1,image2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 837ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Similarity Score: 0.9990686171961896
# 0.9990686171961896

# %%
image1='/content/23-TestCase-116_1_testing.png'
image2='/content/23-TestCase-116_1_training.png'
display_images(image1,image2)
similarity_calculator.compute_similarity(image1,image2)
# Out:
# ...
# 1/1 [==============================] - 1s 514ms/step
# Similarity Score: 0.9999998807907104
# 0.9642367839080488
